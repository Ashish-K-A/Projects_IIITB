# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df1 =
# Out:
#   File "<ipython-input-3-6b707eeae292>", line 2
#     df1 =
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 = pd.read_csv("superstore.csv")
df2.head(20)
# Out:
#           Order ID       Ship Mode      Segment   Region       Product ID  \
# 0   CA-2016-152156    Second Class     Consumer    South  FUR-BO-10001798
# 1   CA-2016-152156    Second Class     Consumer    South  FUR-CH-10000454
# 2   CA-2016-138688    Second Class    Corporate     West  OFF-LA-10000240
# 3   US-2015-108966  Standard Class     Consumer    South  FUR-TA-10000577
# 4   US-2015-108966  Standard Class     Consumer    South  OFF-ST-10000760
# 5   CA-2014-115812  Standard Class     Consumer     West  FUR-FU-10001487
# 6   CA-2014-115812  Standard Class     Consumer     West  OFF-AR-10002833
# 7   CA-2014-115812  Standard Class     Consumer     West  TEC-PH-10002275
# 8   CA-2014-115812  Standard Class     Consumer     West  OFF-BI-10003910
# 9   CA-2014-115812  Standard Class     Consumer     West  OFF-AP-10002892
# 10  CA-2014-115812  Standard Class     Consumer     West  FUR-TA-10001539
# 11  CA-2014-115812  Standard Class     Consumer     West  TEC-PH-10002033
# 12  CA-2017-114412  Standard Class     Consumer    South  OFF-PA-10002365
# 13  CA-2016-161389  Standard Class     Consumer     West  OFF-BI-10003656
# 14  US-2015-118983  Standard Class  Home Office  Central  OFF-AP-10002311
# 15  US-2015-118983  Standard Class  Home Office  Central  OFF-BI-10000756
# 16  CA-2014-105893  Standard Class     Consumer  Central  OFF-ST-10004186
# 17  CA-2014-167164    Second Class     Consumer     West  OFF-ST-10000107
# 18  CA-2014-143336    Second Class     Consumer     West  OFF-AR-10003056
# 19  CA-2014-143336    Second Class     Consumer     West  TEC-PH-10001949
#
#         Sales  Quantity Discount    Profit
# 0    261.9600         2       0%   41.9136
# 1    731.9400         3       0%  219.5820
# 2     14.6200         2       0%    6.8714
# 3    957.5775         5    0.45% -383.0310
# 4     22.3680         2    0.20%    2.5164
# 5     48.8600         7       0%   14.1694
# 6      7.2800         4       0%    1.9656
# 7    907.1520         6    0.20%   90.7152
# 8     18.5040         3    0.20%    5.7825
# 9    114.9000         5       0%   34.4700
# 10  1706.1840         9    0.20%   85.3092
# 11   911.4240         4    0.20%   68.3568
# 12    15.5520         3    0.20%    5.4432
# 13   407.9760         3    0.20%  132.5922
# 14    68.8100         5    0.80% -123.8580
# 15     2.5440         3    0.80%   -3.8160
# 16   665.8800         6       0%   13.3176
# 17    55.5000         2       0%    9.9900
# 18     8.5600         2       0%    2.4824
# 19   213.4800         3    0.20%   16.0110

# %%
df3 = df2[(df2.Profit < 0) & (df2.Sales < 15000)]
sns.jointplot('Sales', 'Profit', df3)
plt.show()
# Out:
# C:\Users\nithi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
#Your code here

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
#Your code here
